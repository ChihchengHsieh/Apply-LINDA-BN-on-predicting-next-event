# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]  =  "TRUE"

from Controller.TrainingController import TrainingController 
trainer = TrainingController()
trainer.train()
# Out:
# =================================================
# | Running on cuda:0
# =================================================
#
# =================================================
# | Preprocessed data loaded successfully
# =================================================
# /home/jrhs/.pyenv/versions/dl/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# /home/jrhs/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Data/BPI2012Dataset.py:257: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sorted_seq_list = [torch.tensor(seq_list[idx])
# | Epoch [1] | Step [200] | lr [0.027500] | Loss: [3.5057] | Acc: [0.2151]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2178] | Loss [3.5019]
# =================================================
# | Epoch [2] | Step [400] | lr [0.015125] | Loss: [3.4967] | Acc: [0.2285]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2175] | Loss [3.5062]
# =================================================
# | Epoch [3] | Step [600] | lr [0.008319] | Loss: [3.5154] | Acc: [0.2130]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2177] | Loss [3.5102]
# =================================================
# | Epoch [4] | Step [800] | lr [0.004575] | Loss: [3.5161] | Acc: [0.2146]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2170] | Loss [3.5131]
# =================================================
# | Epoch [6] | Step [1000] | lr [0.002516] | Loss: [3.5140] | Acc: [0.2193]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2170] | Loss [3.5146]
# =================================================
# | Epoch [7] | Step [1200] | lr [0.001384] | Loss: [3.5356] | Acc: [0.1953]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2176] | Loss [3.5148]
# =================================================
# | Epoch [8] | Step [1400] | lr [0.000761] | Loss: [3.5243] | Acc: [0.2082]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2173] | Loss [3.5156]
# =================================================
# | Epoch [9] | Step [1600] | lr [0.000419] | Loss: [3.4975] | Acc: [0.2339]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2172] | Loss [3.5159]
# =================================================
# | Epoch [10] | Step [1800] | lr [0.000230] | Loss: [3.5022] | Acc: [0.2324]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.2172] | Loss [3.5161]
# =================================================
# | Epoch [11] | Step [1900] | lr [0.000230] | Loss: [3.4982] | Acc: [0.2344]|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2be7ea6182c8> in <module>
#       4 from Controller.TrainingController import TrainingController
#       5 trainer = TrainingController()
# ----> 6 trainer.train()
#
# ~/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Controller/TrainingController.py in train(self)
#     158                 train_data, train_target, train_lengths = train_data.to(
#     159                     self.device), train_target.to(self.device), train_lengths.to(self.device)
# --> 160                 train_loss, train_accuracy = self.train_step(
#     161                     train_data, train_target, train_lengths)
#     162                 self.__steps += 1
#
# ~/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Controller/TrainingController.py in train_step(self, train_data, target, lengths)
#     192         self.model.train()
#     193         self.opt.zero_grad()
# --> 194         loss, accuracy = self.model_step(train_data, target, lengths)
#     195         loss.backward()
#     196         self.opt.step()
#
# ~/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Controller/TrainingController.py in model_step(self, input, target, lengths)
#     218         # Mask the padding
#     219
# --> 220         accuracy = torch.mean(torch.masked_select(
#     221             (torch.argmax(out, dim=-1) == target), target > 0).float())
#     222
#
# KeyboardInterrupt:

# %%
trainer.model.softmax_out
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-d1a6c24fa4ce> in <module>
# ----> 1 trainer.model.softmax_out
#
# ~/.pyenv/versions/dl/lib/python3.9/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     945             if name in modules:
#     946                 return modules[name]
# --> 947         raise AttributeError("'{}' object has no attribute '{}'".format(
#     948             type(self).__name__, name))
#     949
#
# AttributeError: 'BaselineLSTMModel' object has no attribute 'softmax_out'

# %%
trainer.load_json_for_predicting("./PredictingObject/testing_file.json")
# Out:
# =================================================
# | Performing Dataset Loading ...
# =================================================
#
# =================================================
# | Dataset Loading Done!
# =================================================
#
# =================================================
# | Performing Predicting ...
# =================================================
# Predicting cases [====================] 100%
# =================================================
# | Predicting Done!
# =================================================
#
# =================================================
# | Predition result has been save to: PredictingObject/testing_file_result.json
# =================================================

# %%
trainer.model.softmax_out
# Out:
# tensor([[7.3076e-04, 1.7107e-03, 6.2952e-04, 2.7431e-03, 5.8898e-04, 8.5905e-04,
#          1.3844e-03, 2.2826e-03, 1.6294e-03, 2.4130e-02, 1.2644e-03, 4.3777e-04,
#          3.5489e-03, 5.8351e-04, 8.7440e-04, 6.6655e-04, 9.5241e-04, 7.8179e-04,
#          9.9268e-04, 6.4207e-04, 9.4319e-04, 1.5479e-03, 1.3602e-03, 5.4372e-04,
#          9.8698e-04, 1.5563e-03, 9.9800e-03, 7.1533e-04, 9.2172e-01, 9.4820e-04,
#          9.5176e-04, 2.7503e-03, 2.0864e-03, 8.9963e-04, 2.4938e-03, 3.8049e-04,
#          6.8446e-04, 1.0100e-03, 1.0062e-03]], grad_fn=<IndexBackward>)

# %%
import torch

# %%
# chekcing the cuda is working

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True
