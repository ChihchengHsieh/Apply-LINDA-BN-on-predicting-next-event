# %%
import matplotlib.pyplot as plt
from dataclasses import dataclass

# %%
train_accuracy_records = [14.9, 15.8, 21, 19]
train_loss_records = [13.22, 22.4, 11.0, 55]
validation_acuuracy_records = [12.2, 11, 22, 19]
validation_loss_records = [25, 23, 16, 17]

# %%
@dataclass
class TrainingRecord:
    train_accuracy_records: list[float] 
    train_loss_records: list[float] 
    validation_acuuracy_records: list[float] 
    validation_loss_records : list[float]

# %%
class TrainingRecord:
    def __init__(self,):
        self.train_accuracy_records: list[float]  = []
        self.train_loss_records: list[float]  = []
        self.validation_acuuracy_records: list[float]  = []
        self.validation_loss_records : list[float]  = []

# %%
t = TrainingRecord()

# %%
t.train_accuracy_records
# Out:
# []

# %%
t = TrainingRecord([],[],[],[])

# %%
plt.plot(train_accuracy_records)
plt.plot(validation_loss_records)

# %%
plt.subplot(211)
plt.plot(train_accuracy_records)
plt.plot(validation_loss_records)

# %%
plt.subplot(211)
plt.plot(train_accuracy_records)
plt.plot(validation_loss_records)

plt.subplot(212)
plt.plot(train_loss_records)
plt.plot(validation_loss_records)
