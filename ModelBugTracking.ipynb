# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]  =  "TRUE"

from Controller.TrainingController import TrainingController 
trainer = TrainingController()
trainer.train()
# Out:
# | Epoch [0] | Step [120] | lr [0.005000] | Loss: [3.6597] | Acc: [0.0919]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.0886] | Loss [3.6599]
# =================================================
# | Epoch [0] | Step [160] | lr [0.005000] | Loss: [3.6608] | Acc: [0.0862]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.0897] | Loss [3.6608]
# =================================================
# | Epoch [0] | Step [200] | lr [0.004250] | Loss: [3.6614] | Acc: [0.0966]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.0887] | Loss [3.6614]
# =================================================
# | Epoch [0] | Step [240] | lr [0.004250] | Loss: [3.6617] | Acc: [0.1368]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.0894] | Loss [3.6620]
# =================================================
# | Epoch [0] | Step [280] | lr [0.004250] | Loss: [3.6624] | Acc: [0.0680]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.0887] | Loss [3.6622]
# =================================================
# | Epoch [0] | Step [320] | lr [0.004250] | Loss: [3.6625] | Acc: [0.0931]|
# =================================================
# | Performing Validation ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.0888] | Loss [3.6624]
# =================================================
# =================================================
# | Training Done!
# =================================================
#
# =================================================
# | Performing Testing ...
# =================================================
#
# =================================================
# | Evaluation result | Accuracy [0.0839] | Loss [3.6626]
# =================================================
#
# =================================================
# | Running on cpu
# =================================================
#
# =================================================
# | Preprocessed data loaded successfully
# =================================================
# | Epoch [0] | Step [20] | lr [0.005000] | Loss: [3.6516] | Acc: [0.1109]|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b964c3be16e8> in <module>
#       4 from Controller.TrainingController import TrainingController
#       5 trainer = TrainingController()
# ----> 6 trainer.train()
#
# c:\Users\mike8\Documents\GitHub\Apply-LINDA-BN-on-predicting-next-event\Controller\TrainingController.py in train(self)
#     147                 train_data, train_target, train_lengths = train_data.to(
#     148                     self.device), train_target.to(self.device), train_lengths.to(self.device)
# --> 149                 train_loss, train_accuracy = self.train_step(
#     150                     train_data, train_target, train_lengths)
#     151                 self.__steps += 1
#
# c:\Users\mike8\Documents\GitHub\Apply-LINDA-BN-on-predicting-next-event\Controller\TrainingController.py in train_step(self, train_data, target, lengths)
#     182         self.opt.zero_grad()
#     183         loss, accuracy = self.model_step(train_data, target, lengths)
# --> 184         loss.backward()
#     185         self.opt.step()
#     186         if not self.scheduler is None:
#
# ~\anaconda3\envs\py39\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~\anaconda3\envs\py39\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
import torch

# %%
device = torch.device(
            'cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:635467)
# at w.execute (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:634856)
# at w.start (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:629765)
# at processTicksAndRejections (internal/process/task_queues.js:97:5)
# at async t.CellExecutionQueue.executeQueuedCells (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:644951)
# at async t.CellExecutionQueue.start (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:644491)

# %%
torch.cuda.is_available()
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:635467)
# at w.execute (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:634856)
# at w.start (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:629765)
# at processTicksAndRejections (internal/process/task_queues.js:97:5)
# at async t.CellExecutionQueue.executeQueuedCells (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:644951)
# at async t.CellExecutionQueue.start (c:\Users\mike8\.vscode\extensions\ms-toolsai.jupyter-2021.5.702919634\out\client\extension.js:49:644491)

# %%
print("t")
# Out:
# t
