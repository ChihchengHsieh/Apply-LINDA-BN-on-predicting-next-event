# %%
from Data.BPI2012Dataset import BPI2012Dataset
from Parameters.TrainingParameters import TrainingParameters
import math
from datetime import datetime
from IPython.core.display import display, HTML
from Controller.ExplainingController import ExplainingController
import os
import numpy as np
from Utils.PrintUtils import print_big
# Out:
# /Users/jrhs/.pyenv/versions/dl/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
explainer = ExplainingController()
# Out:
# =================================================
# | Model loaded successfully
# =================================================

# %%
np.random.seed(300)

portion = np.random.rand()*.8

explainer.load_dataset()

# Generate a random index
index = np.random.randint(len(explainer.test_dataset))

# Generate an example from test set.
full_trace = explainer.list_of_index_to_vocab(explainer.test_dataset[index]["trace"])
trace_to_predict = full_trace[ : math.ceil(len(full_trace)*portion)]

n_steps = len(full_trace) - len(trace_to_predict) # Can be a fix value.

print_big("Using Portion [%.2f], N_steps [%d]" % (portion, n_steps))
# Out:
# =================================================
# | Preprocessed data loaded successfully: ./datasets/preprocessed/BPI_Challenge_2012/AOW
# =================================================
#
# =================================================
# | Using Portion [0.36], N_steps [6]
# =================================================

# %%
full_trace
# Out:
# ['<SOS>',
#  'A_SUBMITTED_COMPLETE',
#  'A_PARTLYSUBMITTED_COMPLETE',
#  'W_Afhandelen leads_SCHEDULE',
#  'W_Afhandelen leads_START',
#  'W_Afhandelen leads_COMPLETE',
#  'W_Afhandelen leads_START',
#  'A_DECLINED_COMPLETE',
#  'W_Afhandelen leads_COMPLETE',
#  '<EOS>']

# %%
trace_to_predict
# Out:
# ['<SOS>',
#  'A_SUBMITTED_COMPLETE',
#  'A_PARTLYSUBMITTED_COMPLETE',
#  'W_Afhandelen leads_SCHEDULE']

# %%
predicted_list, bn, inference, infoBN, markov_blanket  =  explainer.predict_next_lindaBN_explain(trace_to_predict, n_steps)
html_page = explainer.generate_html_page_from_graphs(bn, inference, infoBN, markov_blanket)
# Out:
# =================================================
# | Performing Predicting ...
# =================================================
#
# =================================================
# | Predicting Done!
# =================================================
#
# =================================================
# | Selecting Greedy Hill Climbing Algorithm
# =================================================
# /Users/jrhs/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Controller/ExplainingController.py:361: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sorted_seq_list = [torch.tensor(seq_list[idx])

# %%
predicted_list
# Out:
# ['<SOS>',
#  'A_SUBMITTED_COMPLETE',
#  'A_PARTLYSUBMITTED_COMPLETE',
#  'W_Afhandelen leads_SCHEDULE',
#  'W_Afhandelen leads_START',
#  'W_Afhandelen leads_COMPLETE',
#  'W_Afhandelen leads_START',
#  'W_Afhandelen leads_COMPLETE',
#  'W_Afhandelen leads_START',
#  'W_Afhandelen leads_COMPLETE']

# %%
display(HTML(html_page))
# Out:
# <h1 style="text-align: center">BN</h1><div style="text-align: center"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="281pt" viewBox="0.00 0.00 360.00 280.57">
# <g id="graph0" class="graph" transform="scale(0.85 0.85) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- step_4 -->
# <g id="node1" class="node">
# <title>step_4</title>
# <g id="a_node1"><a xlink:title="(3) step_4">
# <ellipse fill="#404040" stroke="black" cx="222.2" cy="-162" rx="33.6" ry="18"/>
# <text text-anchor="middle" x="222.2" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">step_4</text>
# </a>
# </g>
# </g>
# <!-- step_2 -->
# <g id="node2" class="node">
# <title>step_2</title>
# <g id="a_node2"><a xlink:title="(1) step_2">
# <ellipse fill="#404040" stroke="black" cx="212.2" cy="-306" rx="33.6" ry="18"/>
# <text text-anchor="middle" x="212.2" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">step_2</text>
# </a>
# </g>
# </g>
# <!-- predict_6 -->
# <g id="node3" class="node">
# <title>predict_6</title>
# <g id="a_node3"><a xlink:title="(9) predict_6">
# <ellipse fill="#404040" stroke="black" cx="44.2" cy="-90" rx="44.39" ry="18"/>
# <text text-anchor="middle" x="44.2" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">predict_6</text>
# </a>
# </g>
# </g>
# <!-- predict_5 -->
# <g id="node5" class="node">
# <title>predict_5</title>
# <g id="a_node5"><a xlink:title="(8) predict_5">
# <ellipse fill="#404040" stroke="black" cx="80.2" cy="-18" rx="44.39" ry="18"/>
# <text text-anchor="middle" x="80.2" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">predict_5</text>
# </a>
# </g>
# </g>
# <!-- predict_6&#45;&gt;predict_5 -->
# <g id="edge6" class="edge">
# <title>predict_6-&gt;predict_5</title>
# <g id="a_edge6"><a xlink:title="(9, 8) : ">
# <path fill="none" stroke="#4a4a4a" d="M52.91,-72.05C57.11,-63.89 62.24,-53.91 66.91,-44.82"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="70.1,-46.28 71.56,-35.79 63.88,-43.08 70.1,-46.28"/>
# </a>
# </g>
# </g>
# <!-- predict_4 -->
# <g id="node4" class="node">
# <title>predict_4</title>
# <g id="a_node4"><a xlink:title="(7) predict_4">
# <ellipse fill="#404040" stroke="black" cx="80.2" cy="-162" rx="44.39" ry="18"/>
# <text text-anchor="middle" x="80.2" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">predict_4</text>
# </a>
# </g>
# </g>
# <!-- predict_4&#45;&gt;predict_6 -->
# <g id="edge4" class="edge">
# <title>predict_4-&gt;predict_6</title>
# <g id="a_edge4"><a xlink:title="(7, 9) : ">
# <path fill="none" stroke="#4a4a4a" d="M71.48,-144.05C67.28,-135.89 62.15,-125.91 57.48,-116.82"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="60.52,-115.08 52.83,-107.79 54.29,-118.28 60.52,-115.08"/>
# </a>
# </g>
# </g>
# <!-- predict_4&#45;&gt;predict_5 -->
# <g id="edge8" class="edge">
# <title>predict_4-&gt;predict_5</title>
# <g id="a_edge8"><a xlink:title="(7, 8) : ">
# <path fill="none" stroke="#4a4a4a" d="M87.09,-144.14C90.9,-133.88 95.25,-120.41 97.2,-108 99.67,-92.19 99.67,-87.81 97.2,-72 95.82,-63.18 93.22,-53.82 90.46,-45.46"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="93.7,-44.13 87.09,-35.86 87.1,-46.45 93.7,-44.13"/>
# </a>
# </g>
# </g>
# <!-- predict_2 -->
# <g id="node6" class="node">
# <title>predict_2</title>
# <g id="a_node6"><a xlink:title="(5) predict_2">
# <ellipse fill="#404040" stroke="black" cx="116.2" cy="-306" rx="44.39" ry="18"/>
# <text text-anchor="middle" x="116.2" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">predict_2</text>
# </a>
# </g>
# </g>
# <!-- predict_2&#45;&gt;predict_4 -->
# <g id="edge3" class="edge">
# <title>predict_2-&gt;predict_4</title>
# <g id="a_edge3"><a xlink:title="(5, 7) : ">
# <path fill="none" stroke="#4a4a4a" d="M94.75,-290.26C83.03,-280.85 69.62,-267.51 63.2,-252 54.82,-231.77 60.58,-207.22 67.58,-189.03"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="70.87,-190.23 71.51,-179.65 64.42,-187.52 70.87,-190.23"/>
# </a>
# </g>
# </g>
# <!-- predict_1 -->
# <g id="node8" class="node">
# <title>predict_1</title>
# <g id="a_node8"><a xlink:title="(4) predict_1">
# <ellipse fill="#404040" stroke="black" cx="222.2" cy="-234" rx="44.39" ry="18"/>
# <text text-anchor="middle" x="222.2" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">predict_1</text>
# </a>
# </g>
# </g>
# <!-- predict_2&#45;&gt;predict_1 -->
# <g id="edge2" class="edge">
# <title>predict_2-&gt;predict_1</title>
# <g id="a_edge2"><a xlink:title="(5, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M138.42,-290.33C153.82,-280.15 174.54,-266.47 191.52,-255.26"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="193.59,-258.09 200,-249.65 189.73,-252.25 193.59,-258.09"/>
# </a>
# </g>
# </g>
# <!-- predict_3 -->
# <g id="node9" class="node">
# <title>predict_3</title>
# <g id="a_node9"><a xlink:title="(6) predict_3">
# <ellipse fill="#404040" stroke="black" cx="116.2" cy="-234" rx="44.39" ry="18"/>
# <text text-anchor="middle" x="116.2" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">predict_3</text>
# </a>
# </g>
# </g>
# <!-- predict_2&#45;&gt;predict_3 -->
# <g id="edge7" class="edge">
# <title>predict_2-&gt;predict_3</title>
# <g id="a_edge7"><a xlink:title="(5, 6) : ">
# <path fill="none" stroke="#4a4a4a" d="M116.2,-287.7C116.2,-279.98 116.2,-270.71 116.2,-262.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="119.7,-262.1 116.2,-252.1 112.7,-262.1 119.7,-262.1"/>
# </a>
# </g>
# </g>
# <!-- step_3 -->
# <g id="node7" class="node">
# <title>step_3</title>
# <g id="a_node7"><a xlink:title="(2) step_3">
# <ellipse fill="#404040" stroke="black" cx="298.2" cy="-306" rx="33.6" ry="18"/>
# <text text-anchor="middle" x="298.2" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">step_3</text>
# </a>
# </g>
# </g>
# <!-- predict_1&#45;&gt;step_4 -->
# <g id="edge1" class="edge">
# <title>predict_1-&gt;step_4</title>
# <g id="a_edge1"><a xlink:title="(4, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M222.2,-215.7C222.2,-207.98 222.2,-198.71 222.2,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="225.7,-190.1 222.2,-180.1 218.7,-190.1 225.7,-190.1"/>
# </a>
# </g>
# </g>
# <!-- predict_3&#45;&gt;predict_4 -->
# <g id="edge5" class="edge">
# <title>predict_3-&gt;predict_4</title>
# <g id="a_edge5"><a xlink:title="(6, 7) : ">
# <path fill="none" stroke="#4a4a4a" d="M107.48,-216.05C103.28,-207.89 98.15,-197.91 93.48,-188.82"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="96.52,-187.08 88.83,-179.79 90.29,-190.28 96.52,-187.08"/>
# </a>
# </g>
# </g>
# <!-- step_1 -->
# <g id="node10" class="node">
# <title>step_1</title>
# <g id="a_node10"><a xlink:title="(0) step_1">
# <ellipse fill="#404040" stroke="black" cx="384.2" cy="-306" rx="33.6" ry="18"/>
# <text text-anchor="middle" x="384.2" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">step_1</text>
# </a>
# </g>
# </g>
# </g>
# </svg></div></br></br></br></br></br><h1 style="text-align: center">Inference</h1><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1620pt" height="1489pt" viewBox="0.00 0.00 1619.50 1489.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1485)">
# <title>structs</title>
# <text text-anchor="middle" x="805.75" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.59ms</text>
# <!-- step_1 -->
# <g id="node1" class="node">
# <title>step_1</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="422,-1481 0,-1481 0,-1209 422,-1209 422,-1481"/>
# <svg viewBox="0 0 560.203125 359.149687" width="422px" height="272px" preserveAspectRatio="xMinYMin meet" x="0" y="-1481"> <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-05-04T22:25:08.885307</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linec

# %%
explainer.save_html(html_page)
# Out:
# =================================================
# | HTML page has been saved to: ./Explanations/2021-05-04 22:25:11.011064_graphs_LINDA-BN.html
# =================================================
