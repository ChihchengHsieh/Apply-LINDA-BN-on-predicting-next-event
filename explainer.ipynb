# %%
from Data.BPI2012Dataset import BPI2012Dataset
from Parameters.TrainingParameters import TrainingParameters
import math
from datetime import datetime
from IPython.core.display import display, HTML
from Controller.ExplainingController import ExplainingController
import os
import numpy as np
from Utils.PrintUtils import print_big

# %%
explainer = ExplainingController()
# Out:
# /home/jrhs/.pyenv/versions/dl/lib/python3.9/site-packages/torch/nn/modules/rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
#
# ...
# | Model loaded successfully
# ...

# %%
np.random.seed()

# portion = np.random.rand()*.8
portion = np.random.rand()*.8


explainer.load_dataset()

# Generate a random index
index = np.random.randint(len(explainer.test_dataset))

# Generate an example from test set.
full_trace = explainer.list_of_index_to_vocab(explainer.test_dataset[index]["trace"])
trace_to_predict = full_trace[ : math.ceil(len(full_trace)*portion)]

n_steps = len(full_trace) - len(trace_to_predict) # Can be a fix value.

print_big("Using Portion [%.2f], N_steps [%d]" % (portion, n_steps))
# Out:
# ...
# | Preprocessed data loaded successfully: ./datasets/preprocessed/BPI_Challenge_2012/A
# ...
#
# ...
# | Using Portion [0.35], N_steps [3]
# ...

# %%
full_trace
# Out:
# ['<SOS>',
#  'A_SUBMITTED_COMPLETE',
#  'A_PARTLYSUBMITTED_COMPLETE',
#  'A_DECLINED_COMPLETE',
#  '<EOS>']

# %%
trace_to_predict
# Out:
# ['<SOS>', 'A_SUBMITTED_COMPLETE']

# %%
predicted_list, bn, inference, infoBN, markov_blanket  =  explainer.predict_next_lindaBN_explain(trace_to_predict, n_steps)
html_page = explainer.generate_html_page_from_graphs(bn, inference, infoBN, markov_blanket)
# Out:
# ...
# | Performing Predicting ...
# ...
#
# ...
# | Predicting Done!
# ...
#
# ...
# | Selecting Greedy Hill Climbing Algorithm
# ...
# /home/jrhs/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Controller/ExplainingController.py:361: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sorted_seq_list = [torch.tensor(seq_list[idx])

# %%
predicted_list
# Out:
# ['<SOS>',
#  'A_SUBMITTED_COMPLETE',
#  'A_PARTLYSUBMITTED_COMPLETE',
#  'A_PREACCEPTED_COMPLETE',
#  'A_ACCEPTED_COMPLETE']

# %%
display(HTML(html_page))
# Out:
# <h1 style="text-align: center">BN</h1><div style="text-align: center"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="216pt" height="260pt" viewBox="0.00 0.00 215.89 260.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- predict_1 -->
# <g id="node1" class="node">
# <title>predict_1</title>
# <g id="a_node1"><a xlink:title="(2) predict_1">
# <ellipse fill="#404040" stroke="black" cx="53.95" cy="-90" rx="53.89" ry="18"/>
# <text text-anchor="middle" x="53.95" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">predict_1</text>
# </a>
# </g>
# </g>
# <!-- step_2 -->
# <g id="node3" class="node">
# <title>step_2</title>
# <g id="a_node3"><a xlink:title="(1) step_2">
# <ellipse fill="#404040" stroke="black" cx="53.95" cy="-18" rx="40.89" ry="18"/>
# <text text-anchor="middle" x="53.95" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">step_2</text>
# ...

# %%
explainer.save_html(html_page)
# Out:
# ...
# | HTML page has been saved to: ./Explanations/2021-05-05 03:50:20.661611_graphs_LINDA-BN.html
# ...

# %%
# Find out the correct and incorrect predictions

# %%
# Out:
# {'bpi_2012_path': './datasets/event_logs/BPI_Challenge_2012.xes',
#  'preprocessed_bpi_2012_folder_path': './datasets/preprocessed/BPI_Challenge_2012',
#  'preprocessed_df_type': 'Pickle',
#  'dataset_split_seed': 12345,
#  'load_model_folder_path': './SavedModels/0.8343_2021-05-04 23:37:50.983155',
#  'max_eos_predicted_length': 50,
#  'loss': 'CrossEntropy',
#  'batch_size': 32}
