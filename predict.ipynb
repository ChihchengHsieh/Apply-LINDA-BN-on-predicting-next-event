# %%
from Controller.PredictingController import PredictingController
predictor = PredictingController()
# Out:
# /Users/jrhs/.pyenv/versions/dl/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e8a77bb473ab> in <module>
# ----> 1 from Controller.PredictingController import PredictingController
#       2 predictor = PredictingController()
#
# ~/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Controller/PredictingController.py in <module>
#       1 from numpy.lib.function_base import select
# ----> 2 from Data.PredictingJsonDataset import PredictingJsonDataset
#       3 import os
#       4 import json
#       5 import torch
#
# ~/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Data/PredictingJsonDataset.py in <module>
#       7 from torch.jit import Error
#       8 from torch.utils.data import Dataset, DataLoader
# ----> 9 import pm4py
#      10 from datetime import timedelta
#      11 import numpy as np
#
# ModuleNotFoundError: No module named 'pm4py'

# %%
predictor.show_model_info()
# Out:
# =================================================
# | Model Structure
# =================================================
# BaselineLSTMModel(
#   (emb): Embedding(39, 256, padding_idx=0)
#   (lstm): LSTM(256, 512, num_layers=2, batch_first=True, dropout=0.2)
#   (batchnorm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (output_net): Sequential(
#     (0): LeakyReLU(negative_slope=0.01, inplace=True)
#     (1): Dropout(p=0.2, inplace=False)
#     (2): Linear(in_features=512, out_features=39, bias=True)
#   )
# )
# =================================================
# | Loaded model has {3711271} parameters
# =================================================
#
# =================================================
# | Loaded model has been trained for [3280] steps, [20] epochs
# =================================================

# %%
predictor.perform_eval_on_testing_set()
# Out:
# =================================================
# | Performing Evaluation on whole dataset ...
# =================================================
# /home/jrhs/Documents/GitHub/Apply-LINDA-BN-on-predicting-next-event/Data/BPI2012Dataset.py:258: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sorted_seq_list = [torch.tensor(seq_list[idx])
#
# =================================================
# | Evaluation result | Accuracy [0.8532] | Loss [3.4188]
# =================================================

# %%
predictor.load_json_for_predicting(path="./PredictingObject/testing_file.json", use_argmax= False)
# Out:
# =================================================
# | Performing Dataset Loading ...
# =================================================
#
# =================================================
# | Dataset Loading Done!
# =================================================
#
# =================================================
# | Performing Predicting ...
# =================================================
# Predicting cases [====================] 100%
# =================================================
# | Predicting Done!
# =================================================
#
# =================================================
# | Predition result has been save to: PredictingObject/testing_file_result.json
# =================================================

# %%
import sys
print("Python version")
print (sys.version)
print("Version info.")
print (sys.version_info)
# Out:
# Python version
# 3.9.4 (default, Apr 22 2021, 23:01:20)
# [Clang 12.0.0 (clang-1200.0.32.29)]
# Version info.
# sys.version_info(major=3, minor=9, micro=4, releaselevel='final', serial=0)

# %%
# Out:
#   File "<ipython-input-3-d8603f9f9bc3>", line 1
#     which python
#           ^
# SyntaxError: invalid syntax
