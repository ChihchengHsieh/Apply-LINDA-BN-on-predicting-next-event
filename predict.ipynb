# %%
from Controller.PredictingController import PredictingController
# Out:
# /Users/jrhs/.pyenv/versions/dl/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
predictor = PredictingController()
# Out:
# ...
# | Preprocessed data loaded successfully
# ...
#
# ...
# | Model loaded successfully
# ...
# /Users/jrhs/.pyenv/versions/dl/lib/python3.9/site-packages/torch/nn/modules/rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
predictor.load_json_for_predicting(path="./PredictingObject/testing_file.json", n_steps=5, use_argmax= False)
# Out:
# ...
# | Performing Dataset Loading ...
# ...
#
# ...
# | Dataset Loading Done!
# ...
#
# ...
# | Performing Predicting ...
# ...
# Predicting cases [====================] 100%
# ...
# | Predicting Done!
# ...
#
# ...
# | Predition result has been save to: PredictingObject/testing_file_result.json
# ...

# %%
predictor.model.softmax_out # Argmax
# Out:
# tensor([[0.0942, 0.0256, 0.0212, 0.0229, 0.0219, 0.0220, 0.0221, 0.0236, 0.0228,
#          0.0251, 0.0236, 0.0219, 0.0244, 0.0219, 0.0224, 0.0237, 0.0214, 0.0236,
#          0.0223, 0.0236, 0.0231, 0.0227, 0.0231, 0.0212, 0.0212, 0.0213, 0.0319,
#          0.0236, 0.0316, 0.0254, 0.0221, 0.0254, 0.0312, 0.0235, 0.0309, 0.0238,
#          0.0229, 0.0239, 0.0212],
#         [0.0942, 0.0256, 0.0212, 0.0229, 0.0219, 0.0220, 0.0221, 0.0236, 0.0228,
#          0.0251, 0.0236, 0.0219, 0.0244, 0.0219, 0.0224, 0.0237, 0.0214, 0.0236,
#          0.0223, 0.0236, 0.0231, 0.0227, 0.0231, 0.0212, 0.0212, 0.0213, 0.0319,
#          0.0236, 0.0316, 0.0254, 0.0221, 0.0254, 0.0312, 0.0235, 0.0309, 0.0238,
#          0.0229, 0.0239, 0.0212]], grad_fn=<SoftmaxBackward>)

# %%
predictor.model.softmax_out # Sample
# Out:
# tensor([[0.0942, 0.0256, 0.0212, 0.0229, 0.0219, 0.0220, 0.0221, 0.0236, 0.0228,
#          0.0251, 0.0236, 0.0219, 0.0244, 0.0219, 0.0224, 0.0237, 0.0214, 0.0236,
#          0.0223, 0.0236, 0.0231, 0.0227, 0.0231, 0.0212, 0.0212, 0.0213, 0.0319,
#          0.0236, 0.0316, 0.0254, 0.0221, 0.0254, 0.0312, 0.0235, 0.0309, 0.0238,
#          0.0229, 0.0239, 0.0212],
#         [0.0941, 0.0256, 0.0212, 0.0229, 0.0219, 0.0220, 0.0221, 0.0236, 0.0228,
#          0.0251, 0.0236, 0.0219, 0.0244, 0.0219, 0.0224, 0.0237, 0.0214, 0.0236,
#          0.0223, 0.0236, 0.0231, 0.0227, 0.0231, 0.0212, 0.0212, 0.0213, 0.0319,
#          0.0236, 0.0316, 0.0254, 0.0221, 0.0254, 0.0312, 0.0235, 0.0309, 0.0238,
#          0.0229, 0.0239, 0.0212]], grad_fn=<SoftmaxBackward>)

# %%
test = {
    "1": [
        "<SOS>",
        "A_ACCEPTED_COMPLETE",
        "A_DECLINED_COMPLETE"
    ],
    "2": [
        "<SOS>",
        "O_CREATED_COMPLETE",
        "W_Beoordelen fraude_COMPLETE",
        "W_Nabellen incomplete dossiers_SCHEDULE"
    ]
}

test_list = [test["1"], test["2"]]

# %%
predictor.predicting_from_list_of_vacab_trace(test_list, n_steps=5, use_argmax=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9c3bcda5d784> in <module>
# ----> 1 predictor.predicting_from_list_of_vacab_trace(test_list, n_steps=5, use_argmax=True)
#
# NameError: name 'predictor' is not defined

# %%
from Controller.TrainingController import TrainingController
# Out:
# /Users/jrhs/.pyenv/versions/dl/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
trainer = TrainingController()
# Out:
# ...
# | Preprocessed data loaded successfully
# ...

# %%
trainer.train()
# Out:
# Using default hidden/Users/jrhs/DL/NextEventPrediction/OurApproach/Data/BPI2012Dataset.py:257: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sorted_seq_list = [torch.tensor(seq_list[idx])
# | Epoch [0] | Step [40] | lr [0.005000] | Loss: [3.6597] | Acc: [0.0728]|
# ...
# | Performing Validation ...
# ...
# Using default hidden
# ...
# | Evaluation result | Accuracy [0.0779] | Loss [3.6596]
# ...
# | Epoch [0] | Step [80] | lr [0.005000] | Loss: [3.6591] | Acc: [0.0000]|
# ...
# | Performing Validation ...
# ...
# Using default hidden
# ...
# | Evaluation result | Accuracy [0.0000] | Loss [3.6586]
# ...
# | Epoch [0] | Step [120] | lr [0.005000] | Loss: [3.6583] | Acc: [0.0000]|
# ...
# | Performing Validation ...
# ...
# Using default hidden
# ...
# | Evaluation result | Accuracy [0.0000] | Loss [3.6589]
# ...
# | Epoch [0] | Step [160] | lr [0.005000] | Loss: [3.6588] | Acc: [0.0000]|
# ...

# %%
trainer.load_json_for_predicting(path="./PredictingObject/testing_file.json", n_steps=None, use_argmax= False)
# Out:
# ...
# | Performing Dataset Loading ...
# ...
#
# ...
# | Dataset Loading Done!
# ...
#
# ...
# | Performing Predicting ...
# ...
# Predicting cases [====================] 100%
# ...
# | Predicting Done!
# ...
#
# ...
# | Predition result has been save to: PredictingObject/testing_file_result.json
# ...

# %%
trainer.predicting_from_list_of_idx_trace([trainer.dataset[0][0], trainer.dataset[1][0]], n_steps= 5, use_argmax= True)
# Out:
# Using input hidden
# [[2,
#   12,
#   9,
#   10,
#   27,
#   28,
#   26,
#   28,
#   3,
#   17,
#   8,
#   15,
#   19,
#   33,
#   26,
#   34,
#   32,
#   34,
#   17,
#   14,
#   15,
#   19,
#   33,
#   32,
#   34,
#   32,
#   34,
#   18,
#   36,
#   32,
#   37,
#   35,
#   37,
#   35,
#   37,
#   13,
#   5,
#   11,
#   4,
#   35,
#   1,
#   0,
#   0,
#   0,
#   0,
#   0],
#  [2,
#   12,
#   9,
#   10,
#   27,
#   28,
#   3,
#   17,
#   8,
#   15,
#   19,
#   33,
#   26,
#   34,
#   32,
#   34,
#   32,
#   34,
#   18,
#   36,
#   32,
#   37,
#   11,
#   5,
#   13,
#   4,
#   35,
#   1,
#   0,
#   0,
#   0,
#   0,
#   0]]

# %%
trainer.model.softmax_out
# Out:
# tensor([[0.0315, 0.0258, 0.0252, 0.0254, 0.0253, 0.0253, 0.0253, 0.0255, 0.0254,
#          0.0257, 0.0255, 0.0253, 0.0255, 0.0253, 0.0253, 0.0254, 0.0252, 0.0255,
#          0.0253, 0.0255, 0.0255, 0.0254, 0.0255, 0.0252, 0.0252, 0.0252, 0.0262,
#          0.0255, 0.0262, 0.0256, 0.0253, 0.0255, 0.0262, 0.0255, 0.0261, 0.0256,
#          0.0254, 0.0256, 0.0252],
#         [0.0315, 0.0258, 0.0252, 0.0254, 0.0253, 0.0253, 0.0253, 0.0255, 0.0254,
#          0.0257, 0.0255, 0.0253, 0.0255, 0.0253, 0.0253, 0.0254, 0.0252, 0.0255,
#          0.0253, 0.0255, 0.0255, 0.0254, 0.0255, 0.0252, 0.0252, 0.0252, 0.0262,
#          0.0255, 0.0262, 0.0256, 0.0253, 0.0255, 0.0262, 0.0255, 0.0261, 0.0256,
#          0.0254, 0.0256, 0.0252]], grad_fn=<IndexBackward>)

# %%
trainer.dataset.index_to_vocab(28)
# Out:
# 'W_Completeren aanvraag_START'

# %%
test_ten = iter(trainer.test_data_loader).next()[2]
# Out:
# /Users/jrhs/DL/NextEventPrediction/OurApproach/Data/BPI2012Dataset.py:257: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sorted_seq_list = [torch.tensor(seq_list[idx])

# %%
torch.masked_select(test_ten ,test_ten > 0)
# Out:
# tensor([12,  9, 10, 27, 28, 26, 28,  3, 17,  8, 15, 19, 33, 26, 34, 18, 36, 32,
#         37, 30, 35, 31, 29, 31, 29, 31, 29, 31, 29, 31, 29, 31, 29, 31, 29, 31,
#         36, 29, 37, 30, 35, 31, 29, 31, 13, 11,  5,  4, 29,  1, 12,  9, 10, 27,
#         28,  3,  8, 17, 15, 19, 33, 26, 34, 32, 34, 32, 34, 32, 34, 32, 34, 18,
#         36, 32, 37, 35, 37, 30, 35, 31, 29, 31, 29, 31, 29, 31, 36, 29, 37, 35,
#         37, 35, 37, 13, 11,  4,  5, 35,  1, 12,  9, 10, 27, 28,  3, 17,  8, 15,
#         19, 33, 26, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 34,
#         32, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 32, 14,  6,
#          1, 12,  9, 21, 22, 10, 27, 20, 28, 26, 28, 26, 28, 26, 28,  3,  8, 17,
#         15, 19, 33, 26, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32, 34, 32,
#         34, 32, 32,  6, 14,  1, 12,  9, 21, 22, 10, 27, 20, 28,  3,  8, 17, 15,
#         19, 33, 26, 34, 32, 34, 18, 36, 32, 37, 30, 35, 31, 29, 31, 29, 31, 36,
# ...

# %%
trainer.model.softmax_out
# Out:
# tensor([[0.0246, 0.0267, 0.0246, 0.0253, 0.0250, 0.0250, 0.0249, 0.0258, 0.0253,
#          0.0262, 0.0257, 0.0250, 0.0257, 0.0250, 0.0249, 0.0255, 0.0247, 0.0255,
#          0.0252, 0.0256, 0.0258, 0.0252, 0.0257, 0.0246, 0.0246, 0.0246, 0.0287,
#          0.0257, 0.0288, 0.0259, 0.0248, 0.0261, 0.0281, 0.0255, 0.0281, 0.0260,
#          0.0253, 0.0260, 0.0246],
#         [0.0246, 0.0267, 0.0246, 0.0253, 0.0250, 0.0250, 0.0249, 0.0258, 0.0253,
#          0.0262, 0.0257, 0.0250, 0.0257, 0.0250, 0.0249, 0.0255, 0.0247, 0.0255,
#          0.0252, 0.0256, 0.0258, 0.0252, 0.0257, 0.0246, 0.0246, 0.0246, 0.0287,
#          0.0257, 0.0288, 0.0259, 0.0248, 0.0261, 0.0281, 0.0255, 0.0281, 0.0260,
#          0.0253, 0.0260, 0.0246]], grad_fn=<IndexBackward>)

# %%
import torch
